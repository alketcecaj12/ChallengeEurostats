# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/nrg_cb_oilm_linear.csv.gz")

# %%
data
# Out:
#                        DATAFLOW        LAST UPDATE freq    nrg_bal       siec  \
# 0        ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M     BKFLOW  O4100_TOT
# 1        ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M     BKFLOW  O4100_TOT
# 2        ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M     BKFLOW  O4100_TOT
# 3        ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M     BKFLOW  O4100_TOT
# 4        ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M     BKFLOW  O4100_TOT
# ...                         ...                ...  ...        ...        ...
# 2236729  ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M  TO_RPI_RO     R5230B
# 2236730  ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M  TO_RPI_RO     R5230B
# 2236731  ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M  TO_RPI_RO     R5230B
# 2236732  ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M  TO_RPI_RO     R5230B
# 2236733  ESTAT:NRG_CB_OILM(1.0)  30/08/23 23:00:00    M  TO_RPI_RO     R5230B
#
#           unit geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0        THS_T  AT     2008-01        0.0      NaN
# 1        THS_T  AT     2008-02        0.0      NaN
# 2        THS_T  AT     2008-03        0.0      NaN
# 3        THS_T  AT     2008-04        0.0      NaN
# 4        THS_T  AT     2008-05        0.0      NaN
# ...        ...  ..         ...        ...      ...
# 2236729  THS_T  TR     2023-01        0.0      NaN
# 2236730  THS_T  TR     2023-02        0.0      NaN
# 2236731  THS_T  TR     2023-03        0.0      NaN
# 2236732  THS_T  TR     2023-04        0.0      NaN
# 2236733  THS_T  TR     2023-05        0.0      NaN
#
# [2236734 rows x 10 columns]

# %%
gbc = data.groupby("geo")

# %%
for i, k in gbc: 
    print(i, len(k))
# Out:
# AL 24686
# AT 67963
# BE 68912
# BG 67753
# CY 66245
# CZ 68208
# DE 69712
# DK 67350
# EE 65299
# EL 69761
# ES 68833
# EU27_2020 69810
# FI 68410
# FR 69598
# GE 14021
# HR 67488
# HU 68711
# IE 67242
# IS 24552
# IT 68911
# LT 67533
# LU 65775
# LV 66475
# MD 14282
# ME 461
# MK 48865
# MT 62558
# NL 70857
# NO 68274
# PL 63848
# PT 68540
# RO 67680
# RS 19140
# SE 71279
# SI 66376
# SK 68053
# TR 67610
# UK 55663

# %%
at = gbc.get_group("AT")

# %%
plt.hist(at.OBS_VALUE)
plt.show()
