# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/nrg_cb_gasm_linear.csv.gz")

# %%
data
# Out:
#                      DATAFLOW        LAST UPDATE freq nrg_bal   siec    unit  \
# 0      ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 1      ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 2      ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 3      ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 4      ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# ...                       ...                ...  ...     ...    ...     ...
# 89533  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 89534  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 89535  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 89536  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 89537  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
#
#       geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0      AL     2018-01        0.0      NaN
# 1      AL     2018-02        0.0      NaN
# 2      AL     2018-03        0.0      NaN
# 3      AL     2018-04        0.0      NaN
# 4      AL     2018-05        0.0      NaN
# ...    ..         ...        ...      ...
# 89533  XK     2022-10        0.0      NaN
# 89534  XK     2022-11        0.0      NaN
# 89535  XK     2022-12        0.0      NaN
# 89536  XK     2023-02        0.0      NaN
# 89537  XK     2023-03        0.0      NaN
#
# [89538 rows x 10 columns]

# %%
gbc = data.groupby("geo")

# %%
for i, k in gbc: 
    print(i, len(k))
# Out:
# AL 1282
# AT 2688
# BE 3012
# BG 2642
# CY 2844
# CZ 2622
# DE 2584
# DK 2735
# EE 2513
# EL 2605
# ES 2702
# EU27_2020 2276
# FI 2449
# FR 2674
# GE 1224
# HR 2568
# HU 2654
# IE 2524
# IS 444
# IT 2653
# LT 2558
# LU 2499
# LV 2590
# MD 894
# ME 468
# MK 2114
# MT 2651
# NL 2689
# NO 2575
# PL 2670
# PT 2661
# RO 2524
# RS 1530
# SE 2532
# SI 2613
# SK 3066
# TR 2557
# UA 454
# UK 1834
# XK 364

# %%
at = gbc.get_group("AT")

# %%
at
# Out:
#                      DATAFLOW        LAST UPDATE freq nrg_bal   siec    unit  \
# 62     ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 63     ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 64     ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 65     ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# 66     ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M      DL  G3000  MIO_M3
# ...                       ...                ...  ...     ...    ...     ...
# 88394  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 88395  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 88396  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 88397  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
# 88398  ESTAT:NRG_CB_GASM(1.0)  30/08/23 23:00:00    M    VENT  G3000  TJ_GCV
#
#       geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# 62     AT     2014-01       29.0      NaN
# 63     AT     2014-02       28.0      NaN
# 64     AT     2014-03       38.0      NaN
# 65     AT     2014-04       35.0      NaN
# 66     AT     2014-05       31.0      NaN
# ...    ..         ...        ...      ...
# 88394  AT     2023-03        0.0      NaN
# 88395  AT     2023-04        0.0      NaN
# 88396  AT     2023-05        0.0      NaN
# 88397  AT     2023-06        0.0      NaN
# 88398  AT     2023-07        0.0      NaN
#
# [2688 rows x 10 columns]

# %%
plt.hist(at.OBS_VALUE)
plt.show()
