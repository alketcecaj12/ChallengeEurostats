# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("data/nrg_cb_em_linear.csv.gz")

# %%
data
# Out:
#                    DATAFLOW        LAST UPDATE freq     nrg_bal   siec unit  \
# 0      ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 1      ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 2      ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 3      ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 4      ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# ...                     ...                ...  ...         ...    ...  ...
# 31147  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 31148  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 31149  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 31150  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 31151  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
#
#       geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
gbc = data.groupby("geo")

# %%
for i, k in gbc: 
    print(i, len(k))
# Out:
# AL 462
# AT 868
# BA 469
# BE 875
# BG 875
# CY 875
# CZ 875
# DE 875
# DK 882
# EE 882
# EL 882
# ES 882
# EU27_2020 748
# FI 882
# FR 889
# GE 455
# HR 774
# HU 882
# IE 882
# IS 632
# IT 822
# LT 882
# LU 875
# LV 882
# MD 294
# ME 478
# MK 695
# MT 846
# NL 875
# NO 889
# PL 882
# PT 882
# RO 875
# RS 630
# SE 882
# SI 875
# SK 834
# TR 767
# UA 364
# UK 658
# XK 119

# %%
at = gbc.get_group("AT")
at
# Out:
#                    DATAFLOW        LAST UPDATE freq     nrg_bal   siec unit  \
# 66     ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 67     ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 68     ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 69     ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# 70     ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M         AIM  E7000  GWH
# ...                     ...                ...  ...         ...    ...  ...
# 27944  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 27945  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 27946  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 27947  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
# 27948  ESTAT:NRG_CB_EM(1.0)  28/08/23 23:00:00    M  TI_EHG_EPS  E7000  GWH
#
#       geo TIME_PERIOD  OBS_VALUE OBS_FLAG
# ...

# %%
plt.hist(at.OBS_VALUE)
plt.show()
